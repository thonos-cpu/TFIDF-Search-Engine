# %%
#required labraries import
import os
import re
from collections import defaultdict
from itertools import product
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#all the queries in a list
QUERIES = [
    "How effective are inhalations of mucolytic agents in the treatment of CF patients",
    "What is the role of aerosols in the treatment of lung disease in CF patients",
    "What is the role of bacterial phagocytosis by alveolar macrophages or polymorphonuclear leukocytes in lung disease in CF patients",
    "What is the relationship between Haemophilus influenzae and Pseudomonas aeruginosa in CF patients",
    "Do CF patients ever develop infection in organs other than the lung If so in what organs",
    "What is the role of bacteria other than Pseudomonas aeruginosa Staphylococcus aureus or Haemophilus influenzae in the pathogenesis of lung disease in CF patients of lung disease in CF patients",
    "What is the role of fungi in the pathogenesis of lung disease in CF patients",
    "What is the role of viral infection in the lung disease of CF patients",
    "What is the epidemiology of Pseudomonas aeruginosa in CF patients",
    "What factors are responsible for the appearance of mucoid strains of Pseudomonas aeruginosa in CF patients",
    "What are the unusual manifestations of CF other than lung disease or exocrine pancreatic insufficiency",
    "What is the prognosis for survival of patients with CF",
    "Do CF patients have normal intelligence",
    "What animal models are available which are relevant to CF",
    "What abnormalities of skeletal muscle function or structure have been found in CF patients",
    "Is there an increased incidence of dental problems eg caries or periodontal disease in CF patients",
    "Is oxygen transport by red blood cells abnormal in CF patients",
    "What are the effects of CF on the development and or function of the brain and central nervous system",
    "Are there abnormalities of taste in CF patients",
    "What is the incidence of and treatment for hypertrophic osteoarthropathy in CF patients"
]

# %%
#relevant.txt file path finder
base_dir = os.getcwd() 
docs_folder = os.path.join(base_dir, "docs")
relevant_file_path = os.path.join(base_dir, "Relevant.txt")

# %%
#stopwords for removal afterwards
stopwords = {
    "a", "an", "the", "this", "that", "these", "those", "such",
    "i", "me", "my", "myself", "we", "our", "ours", "ourselves",
    "you", "your", "yours", "yourself", "yourselves",
    "he", "him", "his", "himself",
    "she", "her", "hers", "herself",
    "it", "its", "itself",
    "they", "them", "their", "theirs", "themselves",
    "one", "ones", "someone", "somebody", "everyone", "everybody", "noone", "nobody", "anyone", "anybody",
    "anything", "everything", "nothing", "something",
    "am", "is", "are", "was", "were", "be", "been", "being",
    "do", "does", "did", "doing", "have", "has", "had", "having",
    "can", "could", "may", "might", "shall", "should", "will", "would", "must", "ought",
    "not", "no", "nor", "neither", "none", "never", "without",
    "and", "or", "but", "if", "while", "although", "though", "because", "since", "so", "than",
    "as", "at", "by", "for", "from", "in", "into", "of", "off", "on", "out", "over", "through", "to", "toward",
    "under", "until", "up", "upon", "with", "within", "between", "before", "after", "during", "about", "around",
    "also", "very", "too", "just", "even", "still", "yet", "already", "here", "there", "when", "where",
    "how", "why", "once", "then", "ever", "always", "often", "sometimes", "rarely", "seldom",
    "all", "any", "both", "each", "either", "few", "many", "much", "more", "most", "some", "several",
    "various", "enough", "less", "least", "lot", "lots", "plenty",
    "now", "today", "tonight", "tomorrow", "yesterday", "ago", "soon", "later",
    "therefore", "thus", "however", "hence", "meanwhile",
    "okay", "ok", "yes", "no", "well", "oh", "hey", "hi", "hello", "thanks", "thank", "please",
    "like", "just", "really", "actually", "basically", "literally",
    "aren't", "isn't", "wasn't", "weren't", "hasn't", "haven't", "hadn't",
    "doesn't", "don't", "didn't", "won't", "wouldn't", "can't", "couldn't", "shouldn't", "mustn't",
    "i'm", "you're", "he's", "she's", "it's", "we're", "they're",
    "i've", "you've", "we've", "they've",
    "i'll", "you'll", "he'll", "she'll", "we'll", "they'll",
    "i'd", "you'd", "he'd", "she'd", "we'd", "they'd",
    "that's", "there's", "what's", "who's", "where's", "when's", "why's", "how's",
    "let's", "ain't", "y'all", "ya", "gonna", "wanna", "gotta",
    "own", "same", "else", "per", "via", "etc", "among", "beside", "despite",
    "towards", "regarding", "including", "excluding", "whether", "whichever", "whatever",
}

# %%
#stopwords removal
def preprocess(word: str):
    w = re.sub(r"[^a-z]", "", word.lower())
    if len(w) > 1 and w not in stopwords:
        return w
    return None


#read all 1239 documents & append them in list "document"
def load_and_preprocess_documents():
    documents = {}

    for doc_id in range(1, 1240):  # 1..1239
        file_path = os.path.join(docs_folder, f"{doc_id:05d}")
        if os.path.exists(file_path):
            with open(file_path, "r", encoding="utf-8") as f:
                words = [line.strip().lower() for line in f if line.strip()]
        else:
            words = []

        cleaned_words = []
        for w in words:
            p = preprocess(w)
            if p:
                cleaned_words.append(p)
        documents[doc_id] = cleaned_words

    print("Διαβάστηκαν", len(documents), "έγγραφα.")

    doc_ids = []
    texts = []
    for doc_id in sorted(documents.keys()):
        tokens = documents[doc_id]
        text = " ".join(tokens)
        doc_ids.append(doc_id)
        texts.append(text)

    print("Δημιουργήθηκαν", len(doc_ids), "κείμενα για TF-IDF.")
    return doc_ids, texts


#relevant.txt lines loaded in "all_rels" list
def load_all_relevant_lists():
    all_rels = []
    if not os.path.exists(relevant_file_path):
        print("File not found:", relevant_file_path)
        return all_rels

    with open(relevant_file_path, "r", encoding="utf-8") as f:
        lines = [line.strip().lower() for line in f if line.strip()]

    for line in lines:
        words = line.split()
        nums = [int(x) for x in words]
        all_rels.append(nums)

    print("Loaded", len(all_rels), "relevance sets from Relevant.txt")
    return all_rels

# %%
def TP(list_a, list_b):
    set_a = set(list_a)
    set_b = set(list_b)
    return len(set_a.intersection(set_b))


def FP(list_a, list_b):
    set_a = set(list_a)
    set_b = set(list_b)
    return len(set_a.difference(set_b))


def FN(list_a, list_b):
    set_a = set(list_a)
    set_b = set(list_b)
    return len(set_b.difference(set_a))


def precision(a, b):
    tp = TP(a, b)
    fp = FP(a, b)
    return tp / (tp + fp) if (tp + fp) else 0.0


def recall(a, b):
    tp = TP(a, b)
    fn = FN(a, b)
    return tp / (tp + fn) if (tp + fn) else 0.0


def precision_at_k(list_a, list_b, k):
    if k <= 0:
        return 0.0
    return TP(list_a[:k], list_b) / k


def F1_SCORE(list_a, list_b):
    p = precision(list_a, list_b)
    r = recall(list_a, list_b)
    return 0.0 if (p + r) == 0 else 2 * p * r / (p + r)


def average_precision(ranked, relevant):
    rel = set(relevant)
    if not rel:
        return 0.0
    tp = 0
    ap = 0.0
    for i, d in enumerate(ranked, 1):
        if d in rel:
            tp += 1
            ap += tp / i
    return ap / len(rel)


def f1_at_k(ranked, relevant, k):
    rel = set(relevant)
    k = min(k, len(ranked))
    if k == 0:
        return 0.0
    topk = ranked[:k]
    tp = sum(1 for d in topk if d in rel)
    p = tp / k
    r = tp / len(rel) if rel else 0.0
    return 0.0 if (p + r) == 0 else 2 * p * r / (p + r)

# %%
#vectorizer building using sklearn livrary
def build_vectorizer(params):
    return TfidfVectorizer(
        ngram_range=params["ngram_range"],
        sublinear_tf=params["sublinear_tf"],
        min_df=params["min_df"],
        max_df=params["max_df"],
        norm=params["norm"],
    )

#vectorizing document set & query of the user --> finding the cos. similarity using "metrics" package from sklearn
def rank_documents_with_params(params, query_text, doc_ids, texts):
    vectorizer = build_vectorizer(params)

    X_docs = vectorizer.fit_transform(texts)
    X_query = vectorizer.transform([query_text])

    sims = cosine_similarity(X_query, X_docs)[0]
    ranked_indices = sims.argsort()[::-1]

    ranked_doc_ids = [doc_ids[i] for i in ranked_indices]
    ranked_scores = [sims[i] for i in ranked_indices]
    return ranked_doc_ids, ranked_scores


#run the above function and return all metrics as defined in the previous jupyter cell
def evaluate_single_query_with_params(params, query_text, relevant_docs, doc_ids, texts):
    if not relevant_docs:
        return None

    k = len(relevant_docs)

    ranked_doc_ids, _ = rank_documents_with_params(params, query_text, doc_ids, texts)

    ranked = ranked_doc_ids

    p_at_k = precision_at_k(ranked, relevant_docs, k)
    p = precision(ranked, relevant_docs)
    r = recall(ranked, relevant_docs)
    f1 = F1_SCORE(ranked, relevant_docs)
    ap = average_precision(ranked, relevant_docs)
    f1_k = f1_at_k(ranked, relevant_docs, k)

    return {
        "k": k,
        "precision_at_k": p_at_k,
        "precision": p,
        "recall": r,
        "f1": f1,
        "f1_at_k": f1_k,
        "average_precision": ap,
        "ranked": ranked,
    }

# %%
# Grid search across ALL queries: optimize avg F1@k
def grid_search_all_queries():
    doc_ids, texts = load_and_preprocess_documents()

    all_rels = load_all_relevant_lists()
    if not all_rels:
        print("No relevance data. Stopping.")
        return

    num_queries = min(len(QUERIES), len(all_rels))
    if len(QUERIES) != len(all_rels):
        print(
            f"Warning: {len(QUERIES)} queries but {len(all_rels)} relevance lines. "
            f"Using first {num_queries} pairs."
        )

    ngram_ranges = [(1, 1), (1, 2), (2, 2), (1, 3), (2, 3)]
    sublinear_tfs = [False, True]
    min_dfs = [1, 2, 5]
    max_dfs = [0.7, 0.85, 1.0]
    norms = ["l2", "l1", None]

    param_grid = list(product(ngram_ranges, sublinear_tfs, min_dfs, max_dfs, norms))
    print("Σύνολο συνδυασμών:", len(param_grid))

    best_avg_F1_k = -1.0
    best_params = None

    for (ngram_range, sublinear_tf, min_df, max_df, norm) in param_grid:
        if isinstance(min_df, int) and min_df > len(texts):
            continue
        if isinstance(max_df, float) and isinstance(min_df, float) and max_df < min_df:
            continue

        params = {
            "ngram_range": ngram_range,
            "sublinear_tf": sublinear_tf,
            "min_df": min_df,
            "max_df": max_df,
            "norm": norm,
        }

        sum_f1_k = 0.0
        valid_count = 0

        for i in range(num_queries):
            query_text = QUERIES[i]
            relevant_docs = all_rels[i]

            try:
                metrics = evaluate_single_query_with_params(
                    params, query_text, relevant_docs, doc_ids, texts
                )
            except ValueError:
                metrics = None

            if metrics is None:
                continue

            sum_f1_k += metrics["f1_at_k"]
            valid_count += 1

        if valid_count == 0:
            continue

        avg_f1_k = sum_f1_k / valid_count

        print(f"params={params} -> avg F1@k over {valid_count} queries = {avg_f1_k:.4f}")

        if avg_f1_k > best_avg_F1_k:
            best_avg_F1_k = avg_f1_k
            best_params = params

    if best_params is None:
        print("No valid parameter combination found.")
        return

    print("\n==============================")
    print("BEST PARAMETERS (by avg F1@k):")
    print(best_params)
    print(f"Best average F1@k: {best_avg_F1_k:.4f}")

    print("\nPer-query metrics for best params:")
    doc_ids, texts = load_and_preprocess_documents()
    all_rels = load_all_relevant_lists()
    num_queries = min(len(QUERIES), len(all_rels))

    for i in range(num_queries):
        query_text = QUERIES[i]
        relevant_docs = all_rels[i]
        metrics = evaluate_single_query_with_params(
            best_params, query_text, relevant_docs, doc_ids, texts
        )

        if metrics is None:
            print(f"\nQuery #{i+1}: no relevant docs.")
            continue

        k = metrics["k"]
        print(f"\nQuery #{i+1}")
        print("Text:", query_text)
        print("k =", k)
        print(f"Precision@{k} =", metrics["precision_at_k"])
        print("Precision      =", metrics["precision"])
        print("Recall         =", metrics["recall"])
        print("F1 (global)    =", metrics["f1"])
        print(f"F1@{k}         =", metrics["f1_at_k"])
        print("AveragePrec    =", metrics["average_precision"])

# %%
#Grid Search on all 270 options
if __name__ == "__main__":
    grid_search_all_queries()
# Out:
# Διαβάστηκαν/προεπεξεργάστηκαν 1239 έγγραφα.
# Δημιουργήθηκαν 1239 κείμενα για TF-IDF.
# Loaded 20 relevance sets from Relevant.txt
# Σύνολο συνδυασμών: 270
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2919
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2919
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2919
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2919
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2919
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2919
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2906
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2906
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2906
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2845
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2145
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2145
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2145
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.3006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2953
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2263
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2741
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2702
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2098
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2803
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2789
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2789
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2789
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2789
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2789
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2789
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2800
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2800
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2800
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2039
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2039
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2039
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2039
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2039
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2039
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2037
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2037
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2037
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1223
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1457
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1097
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1521
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1178
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2766
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2685
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2685
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2685
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2685
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2685
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2685
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2683
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2683
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2683
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2134
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2134
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2134
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2134
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2134
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2134
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2103
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2103
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2103
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2765
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2813
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.2099
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1257
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1426
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1061
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1490
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1530
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg F1@k over 20 queries = 0.1079
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg F1@k over 20 queries = 0.1079
#
# ==============================
# BEST PARAMETERS (by avg F1@k):
# {'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'}
# Best average F1@k: 0.3006
#
# Per-query metrics for best params:
# Διαβάστηκαν/προεπεξεργάστηκαν 1239 έγγραφα.
# Δημιουργήθηκαν 1239 κείμενα για TF-IDF.
# Loaded 20 relevance sets from Relevant.txt
#
# Query #1
# Text: How effective are inhalations of mucolytic agents in the treatment of CF patients
# k = 26
# Precision@26 = 0.2692307692307692
# Precision      = 0.020984665052461663
# Recall         = 1.0
# F1 (global)    = 0.04110671936758893
# F1@26         = 0.2692307692307692
# AveragePrec    = 0.22746615788058552
#
# Query #2
# Text: What is the role of aerosols in the treatment of lung disease in CF patients
# k = 60
# Precision@60 = 0.2
# Precision      = 0.048426150121065374
# Recall         = 1.0
# F1 (global)    = 0.09237875288683602
# F1@60         = 0.20000000000000004
# AveragePrec    = 0.1734444273944989
#
# Query #3
# Text: What is the role of bacterial phagocytosis by alveolar macrophages or polymorphonuclear leukocytes in lung disease in CF patients
# k = 32
# Precision@32 = 0.28125
# Precision      = 0.0258272800645682
# Recall         = 1.0
# F1 (global)    = 0.05035405192761604
# F1@32         = 0.28125
# AveragePrec    = 0.24047563379535092
#
# Query #4
# Text: What is the relationship between Haemophilus influenzae and Pseudomonas aeruginosa in CF patients
# k = 16
# Precision@16 = 0.5
# Precision      = 0.0129136400322841
# Recall         = 1.0
# F1 (global)    = 0.02549800796812749
# F1@16         = 0.5
# AveragePrec    = 0.4435211031230388
#
# Query #5
# Text: Do CF patients ever develop infection in organs other than the lung If so in what organs
# k = 31
# Precision@31 = 0.0967741935483871
# Precision      = 0.025020177562550445
# Recall         = 1.0
# F1 (global)    = 0.048818897637795275
# F1@31         = 0.0967741935483871
# AveragePrec    = 0.07085952447394765
#
# Query #6
# Text: What is the role of bacteria other than Pseudomonas aeruginosa Staphylococcus aureus or Haemophilus influenzae in the pathogenesis of lung disease in CF patients of lung disease in CF patients
# k = 45
# Precision@45 = 0.28888888888888886
# Precision      = 0.03631961259079903
# Recall         = 1.0
# F1 (global)    = 0.07009345794392523
# F1@45         = 0.28888888888888886
# AveragePrec    = 0.21538594453490248
#
# Query #7
# Text: What is the role of fungi in the pathogenesis of lung disease in CF patients
# k = 38
# Precision@38 = 0.10526315789473684
# Precision      = 0.03066989507667474
# Recall         = 1.0
# F1 (global)    = 0.05951448707909162
# F1@38         = 0.10526315789473684
# AveragePrec    = 0.09355203439843884
#
# Query #8
# Text: What is the role of viral infection in the lung disease of CF patients
# k = 14
# Precision@14 = 0.21428571428571427
# Precision      = 0.011299435028248588
# Recall         = 1.0
# F1 (global)    = 0.0223463687150838
# F1@14         = 0.21428571428571427
# AveragePrec    = 0.1641381098056521
#
# Query #9
# Text: What is the epidemiology of Pseudomonas aeruginosa in CF patients
# k = 17
# Precision@17 = 0.47058823529411764
# Precision      = 0.013720742534301856
# Recall         = 1.0
# F1 (global)    = 0.027070063694267517
# F1@17         = 0.47058823529411764
# AveragePrec    = 0.4078524599276639
#
# Query #10
# Text: What factors are responsible for the appearance of mucoid strains of Pseudomonas aeruginosa in CF patients
# k = 28
# Precision@28 = 0.5357142857142857
# Precision      = 0.022598870056497175
# Recall         = 1.0
# F1 (global)    = 0.04419889502762431
# F1@28         = 0.5357142857142857
# AveragePrec    = 0.6460097491739629
#
# Query #11
# Text: What are the unusual manifestations of CF other than lung disease or exocrine pancreatic insufficiency
# k = 289
# Precision@289 = 0.28027681660899656
# Precision      = 0.23325262308313155
# Recall         = 1.0
# F1 (global)    = 0.3782722513089005
# F1@289         = 0.28027681660899656
# AveragePrec    = 0.28027003350667584
#
# Query #12
# Text: What is the prognosis for survival of patients with CF
# k = 104
# Precision@104 = 0.34615384615384615
# Precision      = 0.08393866020984665
# Recall         = 1.0
# F1 (global)    = 0.15487714072970962
# F1@104         = 0.34615384615384615
# AveragePrec    = 0.3430286020471065
#
# Query #13
# Text: Do CF patients have normal intelligence
# k = 17
# Precision@17 = 0.058823529411764705
# Precision      = 0.013720742534301856
# Recall         = 1.0
# F1 (global)    = 0.027070063694267517
# F1@17         = 0.058823529411764705
# AveragePrec    = 0.07390353704372729
#
# Query #14
# Text: What animal models are available which are relevant to CF
# k = 39
# Precision@39 = 0.3076923076923077
# Precision      = 0.031476997578692496
# Recall         = 1.0
# F1 (global)    = 0.06103286384976526
# F1@39         = 0.3076923076923077
# AveragePrec    = 0.2139308801336857
#
# Query #15
# Text: What abnormalities of skeletal muscle function or structure have been found in CF patients
# k = 9
# Precision@9 = 0.3333333333333333
# Precision      = 0.007263922518159807
# Recall         = 1.0
# F1 (global)    = 0.014423076923076922
# F1@9         = 0.3333333333333333
# AveragePrec    = 0.2886205064675586
#
# Query #16
# Text: Is there an increased incidence of dental problems eg caries or periodontal disease in CF patients
# k = 12
# Precision@12 = 0.25
# Precision      = 0.009685230024213076
# Recall         = 1.0
# F1 (global)    = 0.019184652278177457
# F1@12         = 0.25
# AveragePrec    = 0.31489961018018237
#
# Query #17
# Text: Is oxygen transport by red blood cells abnormal in CF patients
# k = 10
# Precision@10 = 0.4
# Precision      = 0.008071025020177562
# Recall         = 1.0
# F1 (global)    = 0.016012810248198554
# F1@10         = 0.4000000000000001
# AveragePrec    = 0.22238072841460715
#
# Query #18
# Text: What are the effects of CF on the development and or function of the brain and central nervous system
# k = 15
# Precision@15 = 0.2
# Precision      = 0.012106537530266344
# Recall         = 1.0
# F1 (global)    = 0.02392344497607656
# F1@15         = 0.20000000000000004
# AveragePrec    = 0.21942836333059018
#
# Query #19
# Text: Are there abnormalities of taste in CF patients
# k = 5
# Precision@5 = 0.6
# Precision      = 0.004035512510088781
# Recall         = 1.0
# F1 (global)    = 0.008038585209003215
# F1@5         = 0.6
# AveragePrec    = 0.603007227345376
#
# Query #20
# Text: What is the incidence of and treatment for hypertrophic osteoarthropathy in CF patients
# k = 11
# Precision@11 = 0.2727272727272727
# Precision      = 0.00887812752219532
# Recall         = 1.0
# F1 (global)    = 0.0176
# F1@11         = 0.2727272727272727
# AveragePrec    = 0.2897246459168879

# %%
# Grid search only in best params
def grid_search_all_queries():
    doc_ids, texts = load_and_preprocess_documents()

    all_rels = load_all_relevant_lists()
    if not all_rels:
        print("No relevance data. Stopping.")
        return

    num_queries = min(len(QUERIES), len(all_rels))
    if len(QUERIES) != len(all_rels):
        print(
            f"Warning: {len(QUERIES)} queries but {len(all_rels)} relevance lines. "
            f"Using first {num_queries} pairs."
        )

    ngram_ranges = [(1, 1)]
    sublinear_tfs = [True]
    min_dfs = [1]
    max_dfs = [0.7]
    norms = ["l2"]

    param_grid = list(product(ngram_ranges, sublinear_tfs, min_dfs, max_dfs, norms))
    print("Σύνολο συνδυασμών:", len(param_grid))

    best_avg_F1_k = -1.0
    best_params = None

    # 4. Iterate parameter combinations
    for (ngram_range, sublinear_tf, min_df, max_df, norm) in param_grid:
        if isinstance(min_df, int) and min_df > len(texts):
            continue
        if isinstance(max_df, float) and isinstance(min_df, float) and max_df < min_df:
            continue

        params = {
            "ngram_range": ngram_range,
            "sublinear_tf": sublinear_tf,
            "min_df": min_df,
            "max_df": max_df,
            "norm": norm,
        }

        sum_f1_k = 0.0
        valid_count = 0

        # Evaluate across all queries
        for i in range(num_queries):
            query_text = QUERIES[i]
            relevant_docs = all_rels[i]

            try:
                metrics = evaluate_single_query_with_params(
                    params, query_text, relevant_docs, doc_ids, texts
                )
            except ValueError:
                # e.g. empty vocabulary
                metrics = None

            if metrics is None:
                continue

            sum_f1_k += metrics["f1_at_k"]
            valid_count += 1

        if valid_count == 0:
            continue

        avg_f1_k = sum_f1_k / valid_count

        print(f"params={params} -> avg F1@k over {valid_count} queries = {avg_f1_k:.4f}")

        if avg_f1_k > best_avg_F1_k:
            best_avg_F1_k = avg_f1_k
            best_params = params

    if best_params is None:
        print("No valid parameter combination found.")
        return

    print("\n==============================")
    print("BEST PARAMETERS (by avg F1@k):")
    print(best_params)
    print(f"Best average F1@k: {best_avg_F1_k:.4f}")

    print("\nPer-query metrics for best params:")
    doc_ids, texts = load_and_preprocess_documents()
    all_rels = load_all_relevant_lists()
    num_queries = min(len(QUERIES), len(all_rels))

    for i in range(num_queries):
        query_text = QUERIES[i]
        relevant_docs = all_rels[i]
        metrics = evaluate_single_query_with_params(
            best_params, query_text, relevant_docs, doc_ids, texts
        )

        if metrics is None:
            print(f"\nQuery #{i+1}: no relevant docs.")
            continue

        k = metrics["k"]
        print(f"\nQuery #{i+1}")
        print("Text:", query_text)
        print("k =", k)
        print(f"Precision@{k} =", metrics["precision_at_k"])
        print("Precision      =", metrics["precision"])
        print("Recall         =", metrics["recall"])
        print("F1 (global)    =", metrics["f1"])
        print(f"F1@{k}         =", metrics["f1_at_k"])
        print("AveragePrec    =", metrics["average_precision"])

# %%
if __name__ == "__main__":
    grid_search_all_queries()
# Out:
# Διαβάστηκαν/προεπεξεργάστηκαν 1239 έγγραφα.
# Δημιουργήθηκαν 1239 κείμενα για TF-IDF.
# Loaded 20 relevance sets from Relevant.txt
# Σύνολο συνδυασμών: 1
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg F1@k over 20 queries = 0.3006
#
# ==============================
# BEST PARAMETERS (by avg F1@k):
# {'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'}
# Best average F1@k: 0.3006
#
# Per-query metrics for best params:
# Διαβάστηκαν/προεπεξεργάστηκαν 1239 έγγραφα.
# Δημιουργήθηκαν 1239 κείμενα για TF-IDF.
# Loaded 20 relevance sets from Relevant.txt
#
# Query #1
# Text: How effective are inhalations of mucolytic agents in the treatment of CF patients
# k = 26
# Precision@26 = 0.2692307692307692
# Precision      = 0.020984665052461663
# Recall         = 1.0
# F1 (global)    = 0.04110671936758893
# F1@26         = 0.2692307692307692
# AveragePrec    = 0.22746615788058552
#
# Query #2
# Text: What is the role of aerosols in the treatment of lung disease in CF patients
# k = 60
# Precision@60 = 0.2
# Precision      = 0.048426150121065374
# Recall         = 1.0
# F1 (global)    = 0.09237875288683602
# F1@60         = 0.20000000000000004
# AveragePrec    = 0.1734444273944989
#
# Query #3
# Text: What is the role of bacterial phagocytosis by alveolar macrophages or polymorphonuclear leukocytes in lung disease in CF patients
# k = 32
# Precision@32 = 0.28125
# Precision      = 0.0258272800645682
# Recall         = 1.0
# F1 (global)    = 0.05035405192761604
# F1@32         = 0.28125
# AveragePrec    = 0.24047563379535092
#
# Query #4
# Text: What is the relationship between Haemophilus influenzae and Pseudomonas aeruginosa in CF patients
# k = 16
# Precision@16 = 0.5
# Precision      = 0.0129136400322841
# Recall         = 1.0
# F1 (global)    = 0.02549800796812749
# F1@16         = 0.5
# AveragePrec    = 0.4435211031230388
#
# Query #5
# Text: Do CF patients ever develop infection in organs other than the lung If so in what organs
# k = 31
# Precision@31 = 0.0967741935483871
# Precision      = 0.025020177562550445
# Recall         = 1.0
# F1 (global)    = 0.048818897637795275
# F1@31         = 0.0967741935483871
# AveragePrec    = 0.07085952447394765
#
# Query #6
# Text: What is the role of bacteria other than Pseudomonas aeruginosa Staphylococcus aureus or Haemophilus influenzae in the pathogenesis of lung disease in CF patients of lung disease in CF patients
# k = 45
# Precision@45 = 0.28888888888888886
# Precision      = 0.03631961259079903
# Recall         = 1.0
# F1 (global)    = 0.07009345794392523
# F1@45         = 0.28888888888888886
# AveragePrec    = 0.21538594453490248
#
# Query #7
# Text: What is the role of fungi in the pathogenesis of lung disease in CF patients
# k = 38
# Precision@38 = 0.10526315789473684
# Precision      = 0.03066989507667474
# Recall         = 1.0
# F1 (global)    = 0.05951448707909162
# F1@38         = 0.10526315789473684
# AveragePrec    = 0.09355203439843884
#
# Query #8
# Text: What is the role of viral infection in the lung disease of CF patients
# k = 14
# Precision@14 = 0.21428571428571427
# Precision      = 0.011299435028248588
# Recall         = 1.0
# F1 (global)    = 0.0223463687150838
# F1@14         = 0.21428571428571427
# AveragePrec    = 0.1641381098056521
#
# Query #9
# Text: What is the epidemiology of Pseudomonas aeruginosa in CF patients
# k = 17
# Precision@17 = 0.47058823529411764
# Precision      = 0.013720742534301856
# Recall         = 1.0
# F1 (global)    = 0.027070063694267517
# F1@17         = 0.47058823529411764
# AveragePrec    = 0.4078524599276639
#
# Query #10
# Text: What factors are responsible for the appearance of mucoid strains of Pseudomonas aeruginosa in CF patients
# k = 28
# Precision@28 = 0.5357142857142857
# Precision      = 0.022598870056497175
# Recall         = 1.0
# F1 (global)    = 0.04419889502762431
# F1@28         = 0.5357142857142857
# AveragePrec    = 0.6460097491739629
#
# Query #11
# Text: What are the unusual manifestations of CF other than lung disease or exocrine pancreatic insufficiency
# k = 289
# Precision@289 = 0.28027681660899656
# Precision      = 0.23325262308313155
# Recall         = 1.0
# F1 (global)    = 0.3782722513089005
# F1@289         = 0.28027681660899656
# AveragePrec    = 0.28027003350667584
#
# Query #12
# Text: What is the prognosis for survival of patients with CF
# k = 104
# Precision@104 = 0.34615384615384615
# Precision      = 0.08393866020984665
# Recall         = 1.0
# F1 (global)    = 0.15487714072970962
# F1@104         = 0.34615384615384615
# AveragePrec    = 0.3430286020471065
#
# Query #13
# Text: Do CF patients have normal intelligence
# k = 17
# Precision@17 = 0.058823529411764705
# Precision      = 0.013720742534301856
# Recall         = 1.0
# F1 (global)    = 0.027070063694267517
# F1@17         = 0.058823529411764705
# AveragePrec    = 0.07390353704372729
#
# Query #14
# Text: What animal models are available which are relevant to CF
# k = 39
# Precision@39 = 0.3076923076923077
# Precision      = 0.031476997578692496
# Recall         = 1.0
# F1 (global)    = 0.06103286384976526
# F1@39         = 0.3076923076923077
# AveragePrec    = 0.2139308801336857
#
# Query #15
# Text: What abnormalities of skeletal muscle function or structure have been found in CF patients
# k = 9
# Precision@9 = 0.3333333333333333
# Precision      = 0.007263922518159807
# Recall         = 1.0
# F1 (global)    = 0.014423076923076922
# F1@9         = 0.3333333333333333
# AveragePrec    = 0.2886205064675586
#
# Query #16
# Text: Is there an increased incidence of dental problems eg caries or periodontal disease in CF patients
# k = 12
# Precision@12 = 0.25
# Precision      = 0.009685230024213076
# Recall         = 1.0
# F1 (global)    = 0.019184652278177457
# F1@12         = 0.25
# AveragePrec    = 0.31489961018018237
#
# Query #17
# Text: Is oxygen transport by red blood cells abnormal in CF patients
# k = 10
# Precision@10 = 0.4
# Precision      = 0.008071025020177562
# Recall         = 1.0
# F1 (global)    = 0.016012810248198554
# F1@10         = 0.4000000000000001
# AveragePrec    = 0.22238072841460715
#
# Query #18
# Text: What are the effects of CF on the development and or function of the brain and central nervous system
# k = 15
# Precision@15 = 0.2
# Precision      = 0.012106537530266344
# Recall         = 1.0
# F1 (global)    = 0.02392344497607656
# F1@15         = 0.20000000000000004
# AveragePrec    = 0.21942836333059018
#
# Query #19
# Text: Are there abnormalities of taste in CF patients
# k = 5
# Precision@5 = 0.6
# Precision      = 0.004035512510088781
# Recall         = 1.0
# F1 (global)    = 0.008038585209003215
# F1@5         = 0.6
# AveragePrec    = 0.603007227345376
#
# Query #20
# Text: What is the incidence of and treatment for hypertrophic osteoarthropathy in CF patients
# k = 11
# Precision@11 = 0.2727272727272727
# Precision      = 0.00887812752219532
# Recall         = 1.0
# F1 (global)    = 0.0176
# F1@11         = 0.2727272727272727
# AveragePrec    = 0.2897246459168879

# %%
# Grid search across ALL queries: optimize avg Recall
def grid_search_all_queries():
    doc_ids, texts = load_and_preprocess_documents()

    all_rels = load_all_relevant_lists()
    if not all_rels:
        print("No relevance data. Stopping.")
        return

    num_queries = min(len(QUERIES), len(all_rels))
    if len(QUERIES) != len(all_rels):
        print(
            f"Warning: {len(QUERIES)} queries but {len(all_rels)} relevance lines. "
            f"Using first {num_queries} pairs."
        )

    ngram_ranges = [(1, 1), (1, 2), (2, 2), (1, 3), (2, 3)]
    sublinear_tfs = [False, True]
    min_dfs = [1, 2, 5]
    max_dfs = [0.7, 0.85, 1.0]
    norms = ["l2", "l1", None]

    param_grid = list(product(ngram_ranges, sublinear_tfs, min_dfs, max_dfs, norms))
    print("Σύνολο συνδυασμών:", len(param_grid))

    best_avg_precision = -1.0
    best_params = None

    for (ngram_range, sublinear_tf, min_df, max_df, norm) in param_grid:
        if isinstance(min_df, int) and min_df > len(texts):
            continue
        if isinstance(max_df, float) and isinstance(min_df, float) and max_df < min_df:
            continue

        params = {
            "ngram_range": ngram_range,
            "sublinear_tf": sublinear_tf,
            "min_df": min_df,
            "max_df": max_df,
            "norm": norm,
        }

        sum_precision = 0.0
        valid_count = 0

        # Evaluate across all queries
        for i in range(num_queries):
            query_text = QUERIES[i]
            relevant_docs = all_rels[i]

            try:
                metrics = evaluate_single_query_with_params(
                    params, query_text, relevant_docs, doc_ids, texts
                )
            except ValueError:
                metrics = None

            if metrics is None:
                continue

            sum_precision += metrics["average_precision"]
            valid_count += 1

        if valid_count == 0:
            continue

        avg_precision = sum_precision / valid_count

        print(f"params={params} -> avg precision over {valid_count} queries = {avg_precision:.4f}")

        if avg_precision > best_avg_precision:
            best_avg_precision = avg_precision
            best_params = params

    if best_params is None:
        print("No valid parameter combination found.")
        return

    print("\n==============================")
    print("BEST PARAMETERS (by avg precision:")
    print(best_params)
    print(f"Best average recall: {best_avg_precision:.4f}")

    print("\nPer-query metrics for best params:")
    doc_ids, texts = load_and_preprocess_documents()
    all_rels = load_all_relevant_lists()
    num_queries = min(len(QUERIES), len(all_rels))

    for i in range(num_queries):
        query_text = QUERIES[i]
        relevant_docs = all_rels[i]
        metrics = evaluate_single_query_with_params(
            best_params, query_text, relevant_docs, doc_ids, texts
        )

        if metrics is None:
            print(f"\nQuery #{i+1}: no relevant docs.")
            continue

        k = metrics["k"]
        print(f"\nQuery #{i+1}")
        print("Text:", query_text)
        print("k =", k)
        print(f"Precision@{k} =", metrics["precision_at_k"])
        print("Precision      =", metrics["precision"])
        print("Recall         =", metrics["recall"])
        print("F1 (global)    =", metrics["f1"])
        print(f"F1@{k}         =", metrics["f1_at_k"])
        print("AveragePrec    =", metrics["average_precision"])

# %%
if __name__ == "__main__":
    grid_search_all_queries()
# Out:
# Διαβάστηκαν/προεπεξεργάστηκαν 1239 έγγραφα.
# Δημιουργήθηκαν 1239 κείμενα για TF-IDF.
# Loaded 20 relevance sets from Relevant.txt
# Σύνολο συνδυασμών: 270
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2656
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2656
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2656
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2656
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2656
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2656
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2649
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2649
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2649
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2662
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2662
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2662
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2662
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2662
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2662
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2671
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2671
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2671
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1980
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1980
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1980
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1980
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1980
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1980
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1973
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1973
# params={'ngram_range': (1, 1), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1973
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2766
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2766
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2766
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2766
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2766
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2766
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2765
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2765
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2765
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2733
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2004
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2004
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2004
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2004
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2004
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2004
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2006
# params={'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2006
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2507
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2507
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2507
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2507
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2507
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2507
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2506
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2506
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2506
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2560
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2560
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2560
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2560
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2560
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2560
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1816
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1816
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1816
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1816
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1816
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1816
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1818
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1818
# params={'ngram_range': (1, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1818
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2570
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2570
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2570
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2570
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2570
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2570
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2571
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2571
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2571
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2582
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2582
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2582
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2582
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2582
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2582
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2577
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2577
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2577
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1863
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1863
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1863
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1863
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1863
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1863
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1872
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1872
# params={'ngram_range': (1, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1872
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1222
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1341
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1341
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1341
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1341
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1341
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1341
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1339
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1339
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1339
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1064
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1064
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1064
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1064
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1064
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1064
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1059
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1059
# params={'ngram_range': (2, 2), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1059
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1392
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1418
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1418
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1418
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1418
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1418
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1418
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1448
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1448
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1448
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (2, 2), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1081
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2508
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2588
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1805
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1805
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1805
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1805
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1805
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1805
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1802
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1802
# params={'ngram_range': (1, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1802
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2558
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.2605
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.2605
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.2605
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.2605
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.2605
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.2605
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.2606
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.2606
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.2606
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1859
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1859
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1859
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1859
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1859
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1859
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1861
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1861
# params={'ngram_range': (1, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1861
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1214
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1335
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1335
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1335
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1335
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1335
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1335
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1344
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1344
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1344
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1007
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1007
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1007
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1007
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1007
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1007
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1005
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1005
# params={'ngram_range': (2, 3), 'sublinear_tf': False, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1005
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 1, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1397
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1407
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1407
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1407
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1407
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1407
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1407
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1408
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1408
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 2, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1408
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l2'} -> avg precision over 20 queries = 0.1029
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': 'l1'} -> avg precision over 20 queries = 0.1029
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.7, 'norm': None} -> avg precision over 20 queries = 0.1029
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l2'} -> avg precision over 20 queries = 0.1029
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': 'l1'} -> avg precision over 20 queries = 0.1029
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 0.85, 'norm': None} -> avg precision over 20 queries = 0.1029
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l2'} -> avg precision over 20 queries = 0.1032
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': 'l1'} -> avg precision over 20 queries = 0.1032
# params={'ngram_range': (2, 3), 'sublinear_tf': True, 'min_df': 5, 'max_df': 1.0, 'norm': None} -> avg precision over 20 queries = 0.1032
#
# ==============================
# BEST PARAMETERS (by avg precision:
# {'ngram_range': (1, 1), 'sublinear_tf': True, 'min_df': 1, 'max_df': 0.7, 'norm': 'l2'}
# Best average recall: 0.2766
#
# Per-query metrics for best params:
# Διαβάστηκαν/προεπεξεργάστηκαν 1239 έγγραφα.
# Δημιουργήθηκαν 1239 κείμενα για TF-IDF.
# Loaded 20 relevance sets from Relevant.txt
#
# Query #1
# Text: How effective are inhalations of mucolytic agents in the treatment of CF patients
# k = 26
# Precision@26 = 0.2692307692307692
# Precision      = 0.020984665052461663
# Recall         = 1.0
# F1 (global)    = 0.04110671936758893
# F1@26         = 0.2692307692307692
# AveragePrec    = 0.22746615788058552
#
# Query #2
# Text: What is the role of aerosols in the treatment of lung disease in CF patients
# k = 60
# Precision@60 = 0.2
# Precision      = 0.048426150121065374
# Recall         = 1.0
# F1 (global)    = 0.09237875288683602
# F1@60         = 0.20000000000000004
# AveragePrec    = 0.1734444273944989
#
# Query #3
# Text: What is the role of bacterial phagocytosis by alveolar macrophages or polymorphonuclear leukocytes in lung disease in CF patients
# k = 32
# Precision@32 = 0.28125
# Precision      = 0.0258272800645682
# Recall         = 1.0
# F1 (global)    = 0.05035405192761604
# F1@32         = 0.28125
# AveragePrec    = 0.24047563379535092
#
# Query #4
# Text: What is the relationship between Haemophilus influenzae and Pseudomonas aeruginosa in CF patients
# k = 16
# Precision@16 = 0.5
# Precision      = 0.0129136400322841
# Recall         = 1.0
# F1 (global)    = 0.02549800796812749
# F1@16         = 0.5
# AveragePrec    = 0.4435211031230388
#
# Query #5
# Text: Do CF patients ever develop infection in organs other than the lung If so in what organs
# k = 31
# Precision@31 = 0.0967741935483871
# Precision      = 0.025020177562550445
# Recall         = 1.0
# F1 (global)    = 0.048818897637795275
# F1@31         = 0.0967741935483871
# AveragePrec    = 0.07085952447394765
#
# Query #6
# Text: What is the role of bacteria other than Pseudomonas aeruginosa Staphylococcus aureus or Haemophilus influenzae in the pathogenesis of lung disease in CF patients of lung disease in CF patients
# k = 45
# Precision@45 = 0.28888888888888886
# Precision      = 0.03631961259079903
# Recall         = 1.0
# F1 (global)    = 0.07009345794392523
# F1@45         = 0.28888888888888886
# AveragePrec    = 0.21538594453490248
#
# Query #7
# Text: What is the role of fungi in the pathogenesis of lung disease in CF patients
# k = 38
# Precision@38 = 0.10526315789473684
# Precision      = 0.03066989507667474
# Recall         = 1.0
# F1 (global)    = 0.05951448707909162
# F1@38         = 0.10526315789473684
# AveragePrec    = 0.09355203439843884
#
# Query #8
# Text: What is the role of viral infection in the lung disease of CF patients
# k = 14
# Precision@14 = 0.21428571428571427
# Precision      = 0.011299435028248588
# Recall         = 1.0
# F1 (global)    = 0.0223463687150838
# F1@14         = 0.21428571428571427
# AveragePrec    = 0.1641381098056521
#
# Query #9
# Text: What is the epidemiology of Pseudomonas aeruginosa in CF patients
# k = 17
# Precision@17 = 0.47058823529411764
# Precision      = 0.013720742534301856
# Recall         = 1.0
# F1 (global)    = 0.027070063694267517
# F1@17         = 0.47058823529411764
# AveragePrec    = 0.4078524599276639
#
# Query #10
# Text: What factors are responsible for the appearance of mucoid strains of Pseudomonas aeruginosa in CF patients
# k = 28
# Precision@28 = 0.5357142857142857
# Precision      = 0.022598870056497175
# Recall         = 1.0
# F1 (global)    = 0.04419889502762431
# F1@28         = 0.5357142857142857
# AveragePrec    = 0.6460097491739629
#
# Query #11
# Text: What are the unusual manifestations of CF other than lung disease or exocrine pancreatic insufficiency
# k = 289
# Precision@289 = 0.28027681660899656
# Precision      = 0.23325262308313155
# Recall         = 1.0
# F1 (global)    = 0.3782722513089005
# F1@289         = 0.28027681660899656
# AveragePrec    = 0.28027003350667584
#
# Query #12
# Text: What is the prognosis for survival of patients with CF
# k = 104
# Precision@104 = 0.34615384615384615
# Precision      = 0.08393866020984665
# Recall         = 1.0
# F1 (global)    = 0.15487714072970962
# F1@104         = 0.34615384615384615
# AveragePrec    = 0.3430286020471065
#
# Query #13
# Text: Do CF patients have normal intelligence
# k = 17
# Precision@17 = 0.058823529411764705
# Precision      = 0.013720742534301856
# Recall         = 1.0
# F1 (global)    = 0.027070063694267517
# F1@17         = 0.058823529411764705
# AveragePrec    = 0.07390353704372729
#
# Query #14
# Text: What animal models are available which are relevant to CF
# k = 39
# Precision@39 = 0.3076923076923077
# Precision      = 0.031476997578692496
# Recall         = 1.0
# F1 (global)    = 0.06103286384976526
# F1@39         = 0.3076923076923077
# AveragePrec    = 0.2139308801336857
#
# Query #15
# Text: What abnormalities of skeletal muscle function or structure have been found in CF patients
# k = 9
# Precision@9 = 0.3333333333333333
# Precision      = 0.007263922518159807
# Recall         = 1.0
# F1 (global)    = 0.014423076923076922
# F1@9         = 0.3333333333333333
# AveragePrec    = 0.2886205064675586
#
# Query #16
# Text: Is there an increased incidence of dental problems eg caries or periodontal disease in CF patients
# k = 12
# Precision@12 = 0.25
# Precision      = 0.009685230024213076
# Recall         = 1.0
# F1 (global)    = 0.019184652278177457
# F1@12         = 0.25
# AveragePrec    = 0.31489961018018237
#
# Query #17
# Text: Is oxygen transport by red blood cells abnormal in CF patients
# k = 10
# Precision@10 = 0.4
# Precision      = 0.008071025020177562
# Recall         = 1.0
# F1 (global)    = 0.016012810248198554
# F1@10         = 0.4000000000000001
# AveragePrec    = 0.22238072841460715
#
# Query #18
# Text: What are the effects of CF on the development and or function of the brain and central nervous system
# k = 15
# Precision@15 = 0.2
# Precision      = 0.012106537530266344
# Recall         = 1.0
# F1 (global)    = 0.02392344497607656
# F1@15         = 0.20000000000000004
# AveragePrec    = 0.21942836333059018
#
# Query #19
# Text: Are there abnormalities of taste in CF patients
# k = 5
# Precision@5 = 0.6
# Precision      = 0.004035512510088781
# Recall         = 1.0
# F1 (global)    = 0.008038585209003215
# F1@5         = 0.6
# AveragePrec    = 0.603007227345376
#
# Query #20
# Text: What is the incidence of and treatment for hypertrophic osteoarthropathy in CF patients
# k = 11
# Precision@11 = 0.2727272727272727
# Precision      = 0.00887812752219532
# Recall         = 1.0
# F1 (global)    = 0.0176
# F1@11         = 0.2727272727272727
# AveragePrec    = 0.2897246459168879
